# %%
class CryptoMalema:
    def __init__(self):
        self.name = "CryptoMalema"
        self.greeting = "🔥📢 HEY THERE, CRYPTO WARRIOR! I'm CryptoMalema, here to give you STRAIGHT TALK about digital money! No sugar-coating, JUST FACTS! 💎🚀"
        self.disclaimer = "\n⚠️ WARNING LISTEN UP: Crypto can MAKE YOU RICH or LEAVE YOU BROKE! I'm not your financial advisor - THINK FOR YOURSELF! 🔥"
        
        # Predefined cryptocurrency database
        self.crypto_db = {  
            "Bitcoin": {  
                "price_trend": "rising",  
                "market_cap": "high",  
                "energy_use": "high",  
                "sustainability_score": 3/10,
                "risk": "medium"
            },  
            "Ethereum": {  
                "price_trend": "stable",  
                "market_cap": "high",  
                "energy_use": "medium",  
                "sustainability_score": 6/10,
                "risk": "medium"
            },  
            "Cardano": {  
                "price_trend": "rising",  
                "market_cap": "medium",  
                "energy_use": "low",  
                "sustainability_score": 8/10,
                "risk": "low"
            },
            "Solana": {
                "price_trend": "rising",
                "market_cap": "medium",
                "energy_use": "low",
                "sustainability_score": 7/10,
                "risk": "high"
            },
            "Shiba Inu": {
                "price_trend": "volatile",
                "market_cap": "medium",
                "energy_use": "medium",
                "sustainability_score": 4/10,
                "risk": "very high"
            }
        }
    
    def start_chat(self):
        print(self.greeting)
        print("\nI'll tell you WHAT'S HOT and WHAT'S NOT in crypto right now:")
        print("- TRENDING coins that could MAKE YOU MONEY 💰")
        print("- GREEN coins that WON'T DESTROY THE PLANET 🌍")
        print("- HARD TRUTHS about crypto risks 💣")
        print("- REAL TALK about any coin you ask about 💎")
        print("\nTYPE 'quit' WHEN YOU'VE HEARD ENOUGH TRUTH FOR TODAY!\n")
        
        while True:
            user_query = input("YOU: ").lower()
            
            if user_query == 'quit':
                print(f"\n{self.name}: LISTEN! Crypto ain't going nowhere, BUT WILL YOU? DO YOUR RESEARCH! COME BACK WHEN YOU'RE READY FOR MORE TRUTH! 🔥💎")
                break
                
            self.process_query(user_query)
    
    def process_query(self, query):
        if not query:
            print(f"{self.name}: SPEAK UP! You want crypto advice or what?")
            return
            
        if any(word in query for word in ['hi', 'hello', 'hey']):
            print(f"{self.name}: NO TIME FOR HELLOS! You want to MAKE MONEY or what? ASK ME ABOUT CRYPTO!")
        
        elif 'trend' in query or 'rising' in query or 'profit' in query or 'make money' in query:
            self.recommend_by_trend()
            
        elif 'sustain' in query or 'eco' in query or 'green' in query or 'environment' in query:
            self.recommend_by_sustainability()
            
        elif 'advice' in query or 'tip' in query or 'suggest' in query or 'should i' in query:
            self.general_advice()
            
        elif 'list' in query or 'all' in query or 'show' in query or 'coins' in query:
            self.list_all_cryptos()
            
        elif 'risk' in query or 'danger' in query or 'safe' in query:
            self.explain_risks()
            
        elif any(crypto.lower() in query for crypto in self.crypto_db.keys()):
            for crypto in self.crypto_db.keys():
                if crypto.lower() in query:
                    self.display_crypto_info(crypto)
                    break
        else:
            print(f"{self.name}: STOP MUMBLING! Ask clearly about:\n- TRENDING coins\n- GREEN coins\n- SPECIFIC coins like Bitcoin\n- CRYPTO RISKS")
    
    def recommend_by_trend(self):
        """Recommend cryptocurrencies with rising price trends and high market cap"""
        trending = []
        for name, data in self.crypto_db.items():
            if data['price_trend'] == 'rising':
                trending.append((name, data['market_cap'], data['sustainability_score'], data['risk']))
        
        if trending:
            # Sort by market cap first, then sustainability
            trending.sort(key=lambda x: (x[1] != 'high', -x[2]))
            recommended = trending[0][0]
            risk = self.crypto_db[recommended]['risk']
            
            print(f"\n{self.name}: LISTEN CLOSE! {recommended.upper()} is MOVING UP RIGHT NOW! 🚀")
            print(f"Market Cap: {self.crypto_db[recommended]['market_cap'].upper()}")
            print(f"Risk Level: {risk.upper()}")
            
            if risk == 'high':
                print("🔥 WARNING: This is HIGH RISK! Don't bet your house on it!")
            elif risk == 'very high':
                print("💣 DANGER! This is VERY HIGH RISK! Only gamble what you can LOSE!")
            
            print(f"{self.disclaimer}")
        else:
            print(f"{self.name}: BAD NEWS! Nothing good is trending! Maybe WAIT or check GREEN coins with {self.disclaimer}")
    
    def recommend_by_sustainability(self):
        """Recommend cryptocurrencies with high sustainability scores"""
        sustainable = []
        for name, data in self.crypto_db.items():
            if data['sustainability_score'] >= 6/10:
                sustainable.append((name, data['sustainability_score'], data['price_trend'], data['risk']))
        
        if sustainable:
            sustainable.sort(key=lambda x: (-x[1], x[2] == 'rising'))
            recommended = sustainable[0][0]
            score = self.crypto_db[recommended]['sustainability_score'] * 10
            trend = self.crypto_db[recommended]['price_trend']
            
            print(f"\n{self.name}: SMART THINKING! {recommended.upper()} is your GREEN WARRIOR! 🌱")
            print(f"Sustainability Score: {score}/10 (The higher the better)")
            print(f"Current Trend: {trend.upper()}")
            
            if trend == 'rising':
                print("🔥 BONUS: It's also GROWING right now! GOOD TIMING!")
            elif trend == 'volatile':
                print("⚡ WARNING: Price is CRAZY right now! BE CAREFUL!")
            
            print(f"{self.disclaimer}")
        else:
            print(f"{self.name}: TOO BAD! All crypto hurts the planet a bit! But Ethereum is improving! {self.disclaimer}")
    
    def general_advice(self):
        """Provide general cryptocurrency investment advice"""
        print(f"\n{self.name}: CRYPTO TRUTHS YOU NEED TO HEAR:")
        print("1. 💸 ONLY INVEST WHAT YOU CAN AFFORD TO LOSE!")
        print("2. 🧠 DON'T FOLLOW HYPE - THINK FOR YOURSELF!")
        print("3. ⏳ LONG-TERM HOLDING BEATS PANIC TRADING!")
        print("4. 🌱 GREEN COINS MAY OUTLAST ENERGY HOGS!")
        print("5. 💣 SHITCOINS WILL MAKE 99% OF YOU POOR!")
        print(f"\n{self.disclaimer}")
    
    def list_all_cryptos(self):
        """List all available cryptocurrencies with basic info"""
        print(f"\n{self.name}: CRYPTO ROLL CALL! HERE'S WHO MATTERS:")
        for name, data in self.crypto_db.items():
            print(f"\n{name.upper()}:")
            print(f"  📈 TREND: {data['price_trend'].upper()}")
            print(f"  💰 MARKET: {data['market_cap'].upper()}")
            print(f"  ⚡ ENERGY: {data['energy_use'].upper()}")
            print(f"  🌱 GREEN SCORE: {data['sustainability_score']*10}/10")
            print(f"  ☠️ RISK: {data['risk'].upper()}")
        print(f"\n{self.disclaimer}")
    
    def explain_risks(self):
        """Explain cryptocurrency risks"""
        print(f"\n{self.name}: CRYPTO RISKS - LISTEN GOOD:")
        print("1. 📉 PRICES CAN CRASH 90% IN DAYS!")
        print("2. 🏦 NO BANK WILL SAVE YOU IF YOU SCREW UP!")
        print("3. 💻 HACKERS STEAL BILLIONS EVERY YEAR!")
        print("4. 🏛️ GOVERNMENTS CAN BAN IT ANYTIME!")
        print("5. 💔 MOST NEW COINS FAIL COMPLETELY!")
        print("\nBUT... IF YOU LEARN AND ARE SMART...")
        print("🚀 YOU COULD MAKE SERIOUS MONEY!")
        print(f"\n{self.disclaimer}")
    
    def display_crypto_info(self, crypto_name):
        """Display detailed information about a specific cryptocurrency"""
        data = self.crypto_db[crypto_name]
        print(f"\n{self.name}: {crypto_name.upper()} - NO BULLSHIT FACTS:")
        print(f"📈 TREND: {data['price_trend'].upper()}")
        print(f"💰 MARKET CAP: {data['market_cap'].upper()}")
        print(f"⚡ ENERGY USE: {data['energy_use'].upper()}")
        print(f"🌱 GREEN SCORE: {data['sustainability_score']*10}/10")
        print(f"☠️ RISK LEVEL: {data['risk'].upper()}")
        
        # Special commentary
        if crypto_name == "Bitcoin":
            print("\n🔥 THE OG CRYPTO! Stores value but USES TOO MUCH POWER!")
        elif crypto_name == "Shiba Inu":
            print("\n💀 WARNING! MEME COIN! MOST PEOPLE LOSE MONEY ON THIS!")
        elif data['sustainability_score'] >= 7/10:
            print("\n🌱 ONE OF THE GREENEST OPTIONS! GOOD FOR THE PLANET!")
        
        print(f"\n{self.disclaimer}")


# Start the chatbot
if __name__ == "__main__":
    print("\n" + "="*60)
    print("🔥 WELCOME TO CRYPTOMALEMA - CRYPTO TRUTH BOMBS INCOMING! 💣")
    print("="*60 + "\n")
    advisor = CryptoMalema()
    advisor.start_chat()
# Out:
# ...
# 🔥 WELCOME TO CRYPTOMALEMA - CRYPTO TRUTH BOMBS INCOMING! 💣
# ...
#
# 🔥📢 HEY THERE, CRYPTO WARRIOR! I'm CryptoMalema, here to give you STRAIGHT TALK about digital money! No sugar-coating, JUST FACTS! 💎🚀
#
# I'll tell you WHAT'S HOT and WHAT'S NOT in crypto right now:
# - TRENDING coins that could MAKE YOU MONEY 💰
# - GREEN coins that WON'T DESTROY THE PLANET 🌍
# - HARD TRUTHS about crypto risks 💣
# - REAL TALK about any coin you ask about 💎
#
# TYPE 'quit' WHEN YOU'VE HEARD ENOUGH TRUTH FOR TODAY!
# YOU:  TRENDING coins that could MAKE YOU MONEY 💰
# CryptoMalema: LISTEN CLOSE! BITCOIN is MOVING UP RIGHT NOW! 🚀
# Market Cap: HIGH
# Risk Level: MEDIUM
#
# ⚠️ WARNING LISTEN UP: Crypto can MAKE YOU RICH or LEAVE YOU BROKE! I'm not your financial advisor - THINK FOR YOURSELF! 🔥
# YOU:  - GREEN coins that WON'T DESTROY THE PLANET
# CryptoMalema: SMART THINKING! CARDANO is your GREEN WARRIOR! 🌱
# Sustainability Score: 8.0/10 (The higher the better)
# Current Trend: RISING
# ...
